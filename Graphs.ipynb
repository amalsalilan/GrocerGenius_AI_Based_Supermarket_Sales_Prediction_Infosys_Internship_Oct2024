# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df = pd.DataFrame(data)   # default plot
df.plot(x='Pulse', y='Maxpulse', title='Calories')
# Out:
# <Axes: title={'center': 'Calories'}, xlabel='Pulse'>

# %%
#Bar plot
df.plot(kind='bar', x ='Pulse', y = 'Calories')
# Out:
# <Axes: xlabel='Pulse'>

# %%
#to get a histogram graph data
import numpy as np
df['Calories'].plot(kind='hist', bins=10)
plt.title('Calories')
plt.show()

# %%
#scatter plot of given data
df.plot(kind='scatter',x = 'Pulse', y ='Calories', title='Scatter Plot')
# Out:
# <Axes: title={'center': 'Scatter Plot'}, xlabel='Pulse', ylabel='Calories'>

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df['Calories'].plot(kind='box', title='Box Plot of Sales')
#shows the distribution of the data like 50% of the data falls below that green line
# Out:
# <Axes: title={'center': 'Box Plot of Sales'}>

# %%
df.plot(kind='pie', y='Pulse', labels=df['Calories'], autopct='%1.1f%%', title='Sales Pie Chart')
#this creates a piechart for the labeled data of pulse ands labels Calories
# Out:
# <Axes: title={'center': 'Sales Pie Chart'}, ylabel='Pulse'>

# %%
df['Calories'].plot(kind='hist',color='green', bins=10)
# Out:
# <Axes: ylabel='Frequency'>
