# %%
import pandas as pd
census = pd.read_csv('test.csv')
census
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
census.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
census.head(7)  #returns the values as much as asked like 10, 5
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDW58       20.750          Low Fat         0.007565
# 1           FDW14        8.300              reg         0.038428
# 2           NCN55       14.600          Low Fat         0.099575
# 3           FDQ58        7.315          Low Fat         0.015388
# 4           FDY38          NaN          Regular         0.118599
# 5           FDH56        9.800          Regular         0.063817
# 6           FDL48       19.350          Regular         0.082602
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# 5  Fruits and Vegetables  117.1492            OUT046
# 6           Baking Goods   50.1034            OUT018
#
# ...

# %%
census.describe() #it gives a summary of all my data available columns
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
census.iloc[0] # it prints the entire row data at the index positon 0 , the format for iloc is rows then columns
# Out:
# Item_Identifier                          FDW58
# Item_Weight                              20.75
# Item_Fat_Content                       Low Fat
# Item_Visibility                       0.007565
# Item_Type                          Snack Foods
# Item_MRP                              107.8622
# Outlet_Identifier                       OUT049
# Outlet_Establishment_Year                 1999
# Outlet_Size                             Medium
# Outlet_Location_Type                    Tier 1
# Outlet_Type                  Supermarket Type1
# Name: 0, dtype: object

# %%
census.iloc[:,0] # it prints out the entire first column data
# Out:
# 0       FDW58
# 1       FDW14
# 2       NCN55
# 3       FDQ58
# 4       FDY38
#         ...
# 5676    FDB58
# 5677    FDD47
# 5678    NCO17
# 5679    FDJ26
# 5680    FDU37
# Name: Item_Identifier, Length: 5681, dtype: object

# %%
census.iloc[0:5] # to access the first 5 rows
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
census.iloc[:, 0:2]   # here we get the data of all the rows as the rows are not mentioned and thereafter we get data from the two columns as mentioned
# Out:
#      Item_Identifier  Item_Weight
# 0              FDW58       20.750
# 1              FDW14        8.300
# 2              NCN55       14.600
# 3              FDQ58        7.315
# 4              FDY38          NaN
# ...              ...          ...
# 5676           FDB58       10.500
# 5677           FDD47        7.600
# 5678           NCO17       10.000
# 5679           FDJ26       15.300
# 5680           FDU37        9.500
#
# [5681 rows x 2 columns]

# %%
census.iloc[[7,18,45],0:5] # got the desired data from rows and columns
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7            FDC48          NaN          Low Fat         0.015782
# 18           NCM42          NaN          Low Fat         0.028184
# 45           FDC26       10.195          Low Fat         0.126278
#
#        Item_Type
# 7   Baking Goods
# 18     Household
# 45        Canned

# %%
census.Item_Fat_Content == 'Regular' # using this i can check which rows contain some specific data that i am looking for finding that
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 5676     True
# 5677     True
# 5678    False
# 5679     True
# 5680     True
# Name: Item_Fat_Content, Length: 5681, dtype: bool

# %%
census.loc[census.Item_Fat_Content == 'Regular']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              FDY38          NaN          Regular         0.118599
# 5              FDH56        9.800          Regular         0.063817
# 6              FDL48       19.350          Regular         0.082602
# 8              FDN33        6.305          Regular         0.123365
# 15             FDM24        6.135          Regular         0.079451
# ...              ...          ...              ...              ...
# 5675           FDW46       13.000          Regular         0.070411
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4                     Dairy  234.2300            OUT027
# ...

# %%
#the 'loc' function is mainly used when we want to select rows and columns based on their labels. Whereas 'iloc' is used when choosing rows and columns based on specific positions

# %%
census.shape[0]   #found out the total number of rows in the dataset
# Out:
# 5681

# %%
average_mrp = census['Item_MRP'].mean()
average_mrp         # Some Mathematical calc to find out mean of given data
# Out:
# 141.02327340256994

# %%
average_max = census['Item_MRP'].max()
average_max       # Some Mathematical calc to find out max of given data
# Out:
# 266.5884

# %%
average_min = census['Item_MRP'].min()
average_min       # Some Mathematical calc to find out min of given data
# Out:
# 31.99

# %%
import pandas as pd
census = pd.read_csv('test.csv')
census
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
Item_content = census['Outlet_Establishment_Year'].value_counts().idxmax() 
Item_content
# Out:
# 1985

# %%
some_unique = census['Outlet_Establishment_Year'].nunique()  #it returns the number of unique values in the dataset
some_unique
# Out:
# 9

# %%
print = census['Item_Weight'].isna().sum()
print
# Out:
# 976

# %%
census[census['Item_Weight'].isna()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              FDY38          NaN          Regular         0.118599
# 7              FDC48          NaN          Low Fat         0.015782
# 12             NCC54          NaN          Low Fat         0.171079
# 18             NCM42          NaN          Low Fat         0.028184
# 23             NCL19          NaN          Low Fat         0.027447
# ...              ...          ...              ...              ...
# 5655           FDX32          NaN          Regular         0.099375
# 5656           FDC39          NaN          Low Fat         0.158425
# 5661           DRG37          NaN          Low Fat         0.000000
# 5665           DRE03          NaN          Low Fat         0.024110
# 5669           FDN31          NaN          Low Fat         0.072529
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4                     Dairy  234.2300            OUT027
# ...

# %%
census.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
subset_one = census[['Item_Weight', 'Item_Fat_Content']]
subset_one             #forming a subset of the dataset according to the desired data required or given
# Out:
#       Item_Weight Item_Fat_Content
# 0          20.750          Low Fat
# 1           8.300              reg
# 2          14.600          Low Fat
# 3           7.315          Low Fat
# 4             NaN          Regular
# ...           ...              ...
# 5676       10.500          Regular
# 5677        7.600          Regular
# 5678       10.000          Low Fat
# 5679       15.300          Regular
# 5680        9.500          Regular
#
# [5681 rows x 2 columns]

# %%
subset_one.iloc[0:10]
# Out:
#    Item_Weight Item_Fat_Content
# 0       20.750          Low Fat
# 1        8.300              reg
# 2       14.600          Low Fat
# 3        7.315          Low Fat
# 4          NaN          Regular
# 5        9.800          Regular
# 6       19.350          Regular
# 7          NaN          Low Fat
# 8        6.305          Regular
# 9        5.985          Low Fat

# %%
subset_one.describe()
# Out:
#        Item_Weight
# count  4705.000000
# mean     12.695633
# std       4.664849
# min       4.555000
# 25%       8.645000
# 50%      12.500000
# 75%      16.700000
# max      21.350000

# %%
subset_one.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 subset_one.dtypes()
#
# TypeError: 'Series' object is not callable
